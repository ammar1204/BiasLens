# %%
from biaslens.analyzer import quick_analyze
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from biaslens.analyzer import quick_analyze
#
# ImportError: cannot import name 'quick_analyze' from 'biaslens.analyzer' (C:\Users\AMMAR\Desktop\BiasLens\biaslens\analyzer.py)
