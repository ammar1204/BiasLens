# %%
from datasets import load_dataset

# %%
dataset = load_dataset('saheedniyi/naijaweb')

# %%
df = dataset['train'].to_pandas()

# %%
df.head()
# Out:
#                                                 text  \
# 0  Governor Samuel Ortom of Benue State\nBy Peter...
# 1  NewsHelm.com offers a unique blend of modernit...
# 2  BY LEVINUS NWABUGHIOGU & EMMAN OVUAKPORIE\nABU...
# 3  Eyitayo Jegede and Jimoh Ibrahim\nBy Ikechukwu...
# 4  Mrs. Helen Mark, wife of Senator David Mark, p...
#
#                                                 link  token_count   section  \
# 0  https://www.vanguardngr.com/2021/03/ortom-comm...          332  Politics
# 1  http://www.newshelm.com/2016/08/photos-preside...          424  Politics
# 2  http://www.vanguardngr.com/2013/11/icpc-recove...          875  Politics
# 3  http://www.vanguardngr.com/2016/11/ondo-s-cour...          729  Politics
# 4  http://www.vanguardngr.com/2016/04/mark-celebr...          545  Politics
#
#    int_score language  language_probability
# 0          1       en              0.999947
# 1          1       en              0.999956
# 2          1       en              0.999979
# ...

# %%
df['text'].sample(10)
# Out:
# 74688     Christian Aburime, the Press Secretary to the ...
# 42231     Late Chief MKO Abiola\nPan Yoruba socio-politi...
# 136453    By Wisdom Nwedene\nReport reaching our news de...
# 245046    The only boiling river in the world steams lik...
# 78772     - Apply New\nApply for new driver's licence\nU...
# 241152    The students of Kaduna State College of Educat...
# 249989    Joshua Daniel is a dynamic and versatile profe...
# 241318    Kim Kardashian is known to be one of the sexie...
# 149829    The Chairman of All Progressives Congress (APC...
# 67406     The popular Islamic scholar, Alhaji Taofeek Ak...
# Name: text, dtype: object
